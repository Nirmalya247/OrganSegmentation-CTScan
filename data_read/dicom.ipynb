# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install pydicom
# !pip install SimpleITK
# !pip install DicomRTTool

# %%
import os
import numpy as np
import pandas as pd
import SimpleITK as sitk
import matplotlib.pyplot as plt
import plotly
from DicomRTTool.ReaderWriter import DicomReaderWriter

# %%
data_root = '/content/drive/MyDrive/Colab Notebooks/project/raw'

# %%
patient1_path = '/content/drive/MyDrive/Colab Notebooks/project/raw/100'

# %%
reader = DicomReaderWriter(description='Anonymized data', arg_max=True)

# %%
reader.walk_through_folders(data_root)
# Out:
# Loading through DICOM files:   0%|          | 0/2 [00:00<?, ?it/s]
# Compiling dictionaries together...
# 0 unique series IDs were found. Default is index 0, to change use set_index(index)

# %%
all_rois = reader.return_rois(print_rois=True)
# Out:
# The following ROIs were found

# %%
pt_index = 100
reader.set_index(pt_index)
reader.get_images()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-20-aa9a2de1bd9a> in <module>
#       1 pt_index = 100
#       2 reader.set_index(pt_index)
# ----> 3 reader.get_images()
#
# /usr/local/lib/python3.7/dist-packages/DicomRTTool/ReaderWriter.py in get_images(self)
#     803     def get_images(self) -> None:
#     804         assert self.index in self.series_instances_dictionary, \
# --> 805             'Index is not present in the dictionary! Set it using set_index(index)'
#     806         index = self.index
#     807         series_instance_uid = self.series_instances_dictionary[index]['SeriesInstanceUID']
#
# AssertionError: Index is not present in the dictionary! Set it using set_index(index)

# %%
image_path = '/content/drive/MyDrive/ColabNotebooks/project/raw/2/First_1.2.840.113619.2.354.3.2013943318.39.1642644788.182.1.dcm'
ds = dicom.dcmread(image_path)

plt.imshow(ds.pixel_array)
